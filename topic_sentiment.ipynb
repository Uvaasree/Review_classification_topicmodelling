# %%
import pandas as pd
df= pd.read_csv('/content/drive/MyDrive/final_project/review_data.csv')
df.dropna(inplace=True)

# %% [markdown]
# # Topic Modeling For Clusters using LDA

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from gensim import corpora
from gensim.models import LdaModel
import pandas as pd
import pickle

with open('/content/drive/MyDrive/final_project/clustering_pipeline.pkl', 'rb') as f:
    pipeline = pickle.load(f)

# Step 1: Predict clusters

df['Cluster'] = pipeline.predict(df['text_'])


# Step 2: Function for Topic Modeling with Gensim LDA
def extract_topics_with_gensim(texts, num_topics=3, num_words=5):
    # Tokenize text
    tokenized_texts = [text.split() for text in texts]

    # Create a dictionary and a corpus
    dictionary = corpora.Dictionary(tokenized_texts)
    corpus = [dictionary.doc2bow(text) for text in tokenized_texts]

    # Train the LDA model
    lda_model = LdaModel(corpus=corpus, num_topics=num_topics, id2word=dictionary, random_state=42)

    # Extract topics
    topics = []
    for topic_id, topic in lda_model.print_topics(num_topics=num_topics, num_words=num_words):
        topics.append(f"Topic {topic_id + 1}: {topic}")
    return topics

# Step 3: Apply LDA for Each Cluster
def lda_topic_modeling(df):
  cluster_topics = {}
  for cluster_num in sorted(df['Cluster'].unique()):
      cluster_texts = df[df['Cluster'] == cluster_num]['text_']
      print(f"\nCluster {cluster_num}: {len(cluster_texts)} reviews")
      topics = extract_topics_with_gensim(cluster_texts, num_topics=3, num_words=5)
      cluster_topics[cluster_num] = topics
      for topic in topics:
          print(topic)

lda_topic_modeling(df[['Cluster','text_']])
# Out:
# Cluster 0: 493 reviews
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# Topic 1: 0.091*"movie" + 0.029*"good" + 0.021*"acting" + 0.017*"great" + 0.016*"love"
# Topic 2: 0.072*"movie" + 0.046*"good" + 0.022*"great" + 0.022*"story" + 0.015*"love"
# Topic 3: 0.083*"movie" + 0.026*"good" + 0.023*"great" + 0.014*"story" + 0.013*"acting"
#
# Cluster 1: 38126 reviews
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# Topic 1: 0.024*"fit" + 0.016*"comfortable" + 0.016*"would" + 0.015*"shoe" + 0.014*"wear"
# Topic 2: 0.035*"love" + 0.023*"size" + 0.020*"great" + 0.014*"bought" + 0.013*"little"
# Topic 3: 0.012*"one" + 0.011*"read" + 0.010*"story" + 0.008*"character" + 0.008*"boot"
#
# Cluster 2: 20 reviews
# Topic 1: 0.211*"good" + 0.128*"effect" + 0.123*"special" + 0.071*"quite" + 0.047*"acting"
# Topic 2: 0.365*"good" + 0.255*"acting" + 0.061*"story" + 0.052*"movie" + 0.028*"pretty"
# Topic 3: 0.308*"good" + 0.175*"story" + 0.044*"acting" + 0.037*"got" + 0.036*"storyline"
#
# Cluster 3: 1791 reviews
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# Topic 1: 0.055*"book" + 0.032*"read" + 0.019*"character" + 0.017*"love" + 0.016*"story"
# Topic 2: 0.062*"book" + 0.037*"story" + 0.029*"read" + 0.024*"character" + 0.015*"well"
# Topic 3: 0.078*"book" + 0.032*"read" + 0.028*"story" + 0.025*"character" + 0.019*"good"
#
# Cluster 4: 1 reviews
# Topic 1: 0.910*"painting" + 0.012*"explain" + 0.011*"cover" + 0.011*"art" + 0.011*"history"
# Topic 2: 0.130*"painting" + 0.109*"cover" + 0.109*"book" + 0.109*"one" + 0.109*"question"
# Topic 3: 0.882*"painting" + 0.016*"one" + 0.016*"book" + 0.015*"question" + 0.015*"answer"

# %%
from sklearn.pipeline import Pipeline
import pickle

with open('/content/drive/MyDrive/final_project/topic_modeling.pkl','wb') as f:
  pickle.dump(lda_topic_modeling,f)
print('file pickled')
# Out:
# file pickled

# %%
with open('/content/drive/MyDrive/final_project/topic_modeling.pkl','rb') as f:
  topic_model=pickle.load(f)

topic_model(df[['Cluster','text_']].iloc[:10])
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# Cluster 1: 10 reviews
# Topic 1: 0.085*"love" + 0.043*"well" + 0.042*"made" + 0.036*"set" + 0.029*"great"
# Topic 2: 0.051*"pillow" + 0.051*"thing" + 0.038*"love" + 0.031*"great" + 0.030*"look"
# Topic 3: 0.068*"great" + 0.040*"love" + 0.040*"information" + 0.039*"price" + 0.039*"missing"

# %% [markdown]
# # Topic Modeling For Clusters using nmf

# %%
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
import pickle

with open('/content/drive/MyDrive/final_project/clustering_pipeline.pkl', 'rb') as f:
    pipeline = pickle.load(f)

# Step 1: Predict clusters

df['Cluster'] = pipeline.predict(df['text_'])

# Step 2: Function for Topic Modeling with NMF
def extract_topics_with_nmf(texts, num_topics=3, num_words=5):
    # Vectorize the texts
    vectorizer = CountVectorizer(stop_words='english')
    X = vectorizer.fit_transform(texts)

    # Apply NMF for topic modeling
    nmf_model = NMF(n_components=num_topics, random_state=42)
    W = nmf_model.fit_transform(X)  # Document-topic matrix
    H = nmf_model.components_  # Topic-term matrix

    # Extract top words for each topic
    topics = []
    feature_names = vectorizer.get_feature_names_out()
    for topic_idx, topic in enumerate(H):
        top_words_idx = topic.argsort()[-num_words:][::-1]
        top_words = [feature_names[i] for i in top_words_idx]
        topics.append(f"Topic {topic_idx + 1}: " + " ".join(top_words))

    return topics

# Step 3: Apply NMF for Topic Modeling on Each Cluster
def nmf_topic_modeling(df):
    cluster_topics = {}
    for cluster_num in sorted(df['Cluster'].unique()):
        cluster_texts = df[df['Cluster'] == cluster_num]['text_']
        print(f"\nCluster {cluster_num}: {len(cluster_texts)} reviews")
        topics = extract_topics_with_nmf(cluster_texts, num_topics=3, num_words=5)
        cluster_topics[cluster_num] = topics
        for topic in topics:
            print(topic)

# Apply NMF topic modeling to each cluster
nmf_topic_modeling(df[['Cluster', 'text_']])
# Out:
# Cluster 0: 493 reviews
# Topic 1: movie good story love like
# Topic 2: special effect notch superb acting
# Topic 3: great action picture story lot
#
# Cluster 1: 38126 reviews
# Topic 1: great like good use little
# Topic 2: book story read character good
# Topic 3: love dog toy son great
#
# Cluster 2: 20 reviews
# Topic 1: acting good great movie really
# Topic 2: story good movie great plot
# Topic 3: good ending effect special movie
#
# Cluster 3: 1791 reviews
# Topic 1: book read good great series
# Topic 2: story character love author good
# Topic 3: liked ending loved story like
#
# Cluster 4: 1 reviews
# Topic 1: painting art history answer book
# Topic 2: painting history book art answer
# Topic 3: cover question explain answer book
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_nmf.py:136: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(res * 2)

# %%
from sklearn.pipeline import Pipeline
import pickle

with open('/content/drive/MyDrive/final_project/topic_modeling_nmf.pkl','wb') as f:
  pickle.dump(nmf_topic_modeling,f)
print('file pickled')
# Out:
# file pickled

# %%
with open('/content/drive/MyDrive/final_project/topic_modeling_nmf.pkl','rb') as f:
  topic_model=pickle.load(f)

topic_model(df[['Cluster','text_']].iloc[:10000])
# Out:
# Cluster 1: 9998 reviews
# Topic 1: great use love like good
# Topic 2: cooky cup cake pie cupcake
# Topic 3: tree beautiful bamboo totally life
#
# Cluster 3: 2 reviews
# Topic 1: like book love son nice
# Topic 2: book little like month item
# Topic 3: cook make knife looking sturdy

# %%
pip freeze > requirements.txt

# %% [markdown]
# # Sentiment analysis

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis")
model = AutoModelForSequenceClassification.from_pretrained("mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/933 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]

# %%
text=[df['text_'].iloc[100]]

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/933 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/328M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
pipe(text)
# Out:
# [{'label': 'positive', 'score': 0.9993795156478882}]

# %%
import pickle
with open('/content/drive/MyDrive/final_project/sentiment_analysis.pkl','wb') as f:
  pickle.dump(pipe,f)
print('file pickled')
# Out:
# file pickled

# %%
for row in range(len(df['text_'])):
  text=[df['text_'].iloc[row]]
  print(f"{text}-- {pipe(text)}")
# Out:
# ['love well made sturdy comfortable love itvery pretty']-- [{'label': 'neutral', 'score': 0.9869396686553955}]
# ['love great upgrade original ive mine couple year']-- [{'label': 'neutral', 'score': 0.703281044960022}]
# ['pillow saved back love look feel pillow']-- [{'label': 'neutral', 'score': 0.997622549533844}]
# ['missing information use great product price']-- [{'label': 'neutral', 'score': 0.9574671387672424}]
# ['nice set good quality set two month']-- [{'label': 'positive', 'score': 0.9956064820289612}]
# ['wanted different flavor']-- [{'label': 'neutral', 'score': 0.999836802482605}]
# ['perfect touch thing wish little space']-- [{'label': 'neutral', 'score': 0.9998249411582947}]
# ['done fit well look great love smoothness edge extra']-- [{'label': 'positive', 'score': 0.7940554022789001}]
# ['great big number easy read thing didnt like size']-- [{'label': 'neutral', 'score': 0.9997342228889465}]
# ['son love comforter well made also baby']-- [{'label': 'neutral', 'score': 0.9994683861732483}]
# ['advertised th one ive problem really']-- [{'label': 'neutral', 'score': 0.9998739957809448}]
# ['handy one kid tool included package one']-- [{'label': 'neutral', 'score': 0.999871015548706}]
# ['someone say oriental great product']-- [{'label': 'neutral', 'score': 0.7659578323364258}]
# ['flimsy quality would expect piece furniture']-- [{'label': 'neutral', 'score': 0.9975177049636841}]
# ['make may tea stirring problem kind hard put']-- [{'label': 'neutral', 'score': 0.9998371601104736}]
# ['absolutely adorable excellent price wooden one month']-- [{'label': 'neutral', 'score': 0.9564201235771179}]
# ['love perfect size entire familyvery good quality']-- [{'label': 'neutral', 'score': 0.9979051351547241}]
# ['look beautiful nice problem really mesh one']-- [{'label': 'neutral', 'score': 0.9914562106132507}]
# ['exactly would expect love look feel pillow']-- [{'label': 'neutral', 'score': 0.9997579455375671}]
# ['star would highly recommend item love blanket']-- [{'label': 'neutral', 'score': 0.9893065094947815}]
# ['great little egg masher month']-- [{'label': 'neutral', 'score': 0.9998620748519897}]
# ['advertised easy use love color also dimension']-- [{'label': 'neutral', 'score': 0.9998353719711304}]
# ['exactly pictured love look feel pillow']-- [{'label': 'neutral', 'score': 0.9998388290405273}]
# ['fantastic wanted love look feel pillow']-- [{'label': 'neutral', 'score': 0.999643087387085}]
# ['supposed come extra hardware problem really vacuum']-- [{'label': 'neutral', 'score': 0.8171266913414001}]
# ['easy use seems easy way make smoothie small person']-- [{'label': 'neutral', 'score': 0.9993797540664673}]
# ['accustomed reason gave star']-- [{'label': 'neutral', 'score': 0.9991229176521301}]
# ['nice product seller yes thin plastic piece however handle']-- [{'label': 'neutral', 'score': 0.999863862991333}]
# ['good bought second set look like first one sure']-- [{'label': 'neutral', 'score': 0.9998180270195007}]
# ['wonderful aroma throughout house problem kind hard put']-- [{'label': 'neutral', 'score': 0.880325436592102}]
# ['received time flat love look husband like']-- [{'label': 'neutral', 'score': 0.9995964169502258}]
# ['okay nice one got local store']-- [{'label': 'neutral', 'score': 0.9832646250724792}]
# ['gave away thought would good addition kitchen']-- [{'label': 'neutral', 'score': 0.9694247841835022}]
# ['product fine wish option separate handle']-- [{'label': 'neutral', 'score': 0.9998852014541626}]
# ['awesome say material good quality decent']-- [{'label': 'neutral', 'score': 0.9696168303489685}]
# ['way heavy everyday use reason gave star one']-- [{'label': 'neutral', 'score': 0.999846339225769}]
# ['well made work great wooden part cup couple']-- [{'label': 'neutral', 'score': 0.9955294728279114}]
# ['bought go old suction cup also love removable']-- [{'label': 'neutral', 'score': 0.999756395816803}]
# ['expected look great design make nice place baby']-- [{'label': 'positive', 'score': 0.9680784344673157}]
# ['awful experience everything stuck cooked evenly problem really']-- [{'label': 'neutral', 'score': 0.9982683658599854}]
# ['great job keeping suction also love doesnt slide']-- [{'label': 'positive', 'score': 0.7211896181106567}]
# ['sheet color nice buy size town']-- [{'label': 'neutral', 'score': 0.9996750354766846}]
# ['save instead original shipping box keep moneyvery pretty']-- [{'label': 'positive', 'score': 0.98078852891922}]
# ['towel real nice love feel nice feel']-- [{'label': 'neutral', 'score': 0.9756875038146973}]
# ['work great easy clean easy clean purchasing morevery pretty']-- [{'label': 'neutral', 'score': 0.9773491024971008}]
# ['alright pricebut little disappointed quality product']-- [{'label': 'negative', 'score': 0.9940398931503296}]
# ['great quality beautiful color one month love']-- [{'label': 'neutral', 'score': 0.998553454875946}]
# ['put paper one corner cabinet put piece paper corner']-- [{'label': 'neutral', 'score': 0.9998599290847778}]
# ['great sticker little small reason gave star one']-- [{'label': 'neutral', 'score': 0.9997474551200867}]
# ['great quality fabric look great thick enough hold small amount coffee']-- [{'label': 'neutral', 'score': 0.9940390586853027}]
# ['perfect exactly need keep long time']-- [{'label': 'neutral', 'score': 0.9998362064361572}]
# ['love movie time took finish keep review next time']-- [{'label': 'neutral', 'score': 0.9998435974121094}]
# ['seal properly atrocious little one feel like break throw']-- [{'label': 'negative', 'score': 0.923781156539917}]
# ['got third time small dog son love throw']-- [{'label': 'neutral', 'score': 0.9998388290405273}]
# ['excellent product much better quality one get walmart']-- [{'label': 'positive', 'score': 0.9989144802093506}]
# ['perfect exactly looking']-- [{'label': 'neutral', 'score': 0.999468982219696}]
# ['great purchase cant beat price']-- [{'label': 'positive', 'score': 0.7410852909088135}]
# ['say cheap work intended']-- [{'label': 'neutral', 'score': 0.9997425675392151}]
# ['nice sturdy like color choice']-- [{'label': 'neutral', 'score': 0.999407172203064}]
# ['nice bowl fast shipping']-- [{'label': 'neutral', 'score': 0.9995492100715637}]
# ['great cup last forever keep thing cool warm']-- [{'label': 'neutral', 'score': 0.9998102784156799}]
# ['love thought would bit bigger']-- [{'label': 'neutral', 'score': 0.9985604882240295}]
# ['excellent quality product perfect ccozinha']-- [{'label': 'positive', 'score': 0.6506994962692261}]
# ['fan really pretty actually use']-- [{'label': 'neutral', 'score': 0.9997240900993347}]
# ['super rough soft wash cloth like bar towel']-- [{'label': 'neutral', 'score': 0.9998713731765747}]
# ['like little guy use often small']-- [{'label': 'neutral', 'score': 0.9998713731765747}]
# ['perfect size easy unfold topremoves storage love']-- [{'label': 'neutral', 'score': 0.9998000264167786}]
# ['good job difficult use']-- [{'label': 'neutral', 'score': 0.9847379922866821}]
# ['frame beautifully crafted look great picture']-- [{'label': 'neutral', 'score': 0.9700486063957214}]
# ['hot cocoa finally perfect product fabulous']-- [{'label': 'positive', 'score': 0.9682877659797668}]
# ['bought friend love']-- [{'label': 'neutral', 'score': 0.9998247027397156}]
# ['soft great quality low price']-- [{'label': 'neutral', 'score': 0.9966334700584412}]
# ['purchased christmas gift love']-- [{'label': 'neutral', 'score': 0.9998278617858887}]
# ['accurate description work great came time im happy']-- [{'label': 'positive', 'score': 0.9825767874717712}]
# ['use duvet cover fluffy perfect fit']-- [{'label': 'neutral', 'score': 0.9993023872375488}]
# ['one softest blanket ever nice cozy']-- [{'label': 'neutral', 'score': 0.9995822310447693}]
# ['smell great fine mist dry quickly favorite']-- [{'label': 'neutral', 'score': 0.999506950378418}]
# ['exactly expecting perfect curtain bedroom']-- [{'label': 'neutral', 'score': 0.994679868221283}]
# ['wanted hang pant skirt']-- [{'label': 'neutral', 'score': 0.9998487234115601}]
# ['kind small looking something larger']-- [{'label': 'neutral', 'score': 0.9998502731323242}]
# ['little pricey']-- [{'label': 'neutral', 'score': 0.9997465014457703}]
# ['work great charge kept day long']-- [{'label': 'neutral', 'score': 0.9960307478904724}]
# ['nice quality frame good price']-- [{'label': 'positive', 'score': 0.7047284245491028}]
# ['job nothing special hard install']-- [{'label': 'neutral', 'score': 0.9998750686645508}]
# ['item described arrived timely manner']-- [{'label': 'neutral', 'score': 0.9998856782913208}]
# ['bought sent one back didnt work']-- [{'label': 'neutral', 'score': 0.9998173117637634}]
# ['made well hold make brush pencil mascara etc']-- [{'label': 'neutral', 'score': 0.9998675584793091}]
# ['shed would buy ever blanket']-- [{'label': 'neutral', 'score': 0.9998493194580078}]
# ['work great pyrex id expect nothing less']-- [{'label': 'positive', 'score': 0.600598156452179}]
# ['like little opener real easy hand']-- [{'label': 'neutral', 'score': 0.9997984766960144}]
# ['perfect love everything look great kitchen']-- [{'label': 'neutral', 'score': 0.9685620069503784}]
# ['air tight work great glad got']-- [{'label': 'positive', 'score': 0.998365581035614}]
# ['cute good quality fabric zipper worked well']-- [{'label': 'positive', 'score': 0.9970868229866028}]
# ['great send grandkids halloween treat']-- [{'label': 'neutral', 'score': 0.9994895458221436}]
# ['save ton using instead paper towel']-- [{'label': 'neutral', 'score': 0.9998558759689331}]
# ['weak barely bring air']-- [{'label': 'neutral', 'score': 0.9897093176841736}]
# ['great set glass good quality comfortable handle']-- [{'label': 'neutral', 'score': 0.992230236530304}]
# ['feel cool touch super hard']-- [{'label': 'neutral', 'score': 0.9997456669807434}]
# ['cute made well grand daughter love']-- [{'label': 'neutral', 'score': 0.9859291911125183}]
# ['work expected connecting cctv power supply camera']-- [{'label': 'neutral', 'score': 0.9998929500579834}]
# ['soft definitely better quality expecting']-- [{'label': 'positive', 'score': 0.9993795156478882}]
# ['nice contemporary great price easy assemble']-- [{'label': 'neutral', 'score': 0.9937475919723511}]
# ['super cute appears great quality highly recommend']-- [{'label': 'neutral', 'score': 0.6459084153175354}]
# ['really cool actually boyfriend loved']-- [{'label': 'neutral', 'score': 0.9952465891838074}]
# ['bought gift cousin nice']-- [{'label': 'neutral', 'score': 0.9991157650947571}]
# ['stopped working one use still waiting refund']-- [{'label': 'neutral', 'score': 0.9987660646438599}]
# ['cute reasonably price happy purchase']-- [{'label': 'positive', 'score': 0.9911030530929565}]
# ['well received comfortable gave gift dialysis patient']-- [{'label': 'positive', 'score': 0.9634191393852234}]
# ['expected poor quality']-- [{'label': 'negative', 'score': 0.9937533736228943}]
# ['easy review kid dd love thanks']-- [{'label': 'neutral', 'score': 0.9972811937332153}]
# ['really ruff foot feel sturdy keep foot chair']-- [{'label': 'neutral', 'score': 0.9979628324508667}]
# ['order place special photo wall weve couple week']-- [{'label': 'neutral', 'score': 0.9998761415481567}]
# ['baby like thermal insulation help keep food warmer thermal insulation help keep']-- [{'label': 'positive', 'score': 0.778200089931488}]
# ['like wish wide opening also love made']-- [{'label': 'neutral', 'score': 0.9427623748779297}]
# ['love pyrex quality set best purchasing future']-- [{'label': 'positive', 'score': 0.9660011529922485}]
# ['perfect additional storage convenience problem really vacuum']-- [{'label': 'negative', 'score': 0.9906208515167236}]
# ['smell great im pretty happy quality quality productthis']-- [{'label': 'positive', 'score': 0.9975833892822266}]
# ['turquoise almost neon bright pink']-- [{'label': 'neutral', 'score': 0.9998679161071777}]
# ['easy hold material nice thick keep shelf order']-- [{'label': 'neutral', 'score': 0.9996968507766724}]
# ['work great chocolate yogurt fruit also love removable']-- [{'label': 'neutral', 'score': 0.9952011108398438}]
# ['love think buy morevery nice set knife one']-- [{'label': 'neutral', 'score': 0.9992293119430542}]
# ['nice small ottoman big small']-- [{'label': 'neutral', 'score': 0.9998669624328613}]
# ['look great kitchen problem kind hard put']-- [{'label': 'neutral', 'score': 0.9974132180213928}]
# ['bought father day gift needed love']-- [{'label': 'neutral', 'score': 0.9997134804725647}]
# ['great winter month soft comfortable ive slept week']-- [{'label': 'neutral', 'score': 0.9417546391487122}]
# ['nice soft sheet find difficult put bed warm']-- [{'label': 'neutral', 'score': 0.9995054006576538}]
# ['beautifully made sturdy comfortable chair comfortable functional']-- [{'label': 'neutral', 'score': 0.9705904126167297}]
# ['need buy two go wide wooden leg bedding one']-- [{'label': 'neutral', 'score': 0.9998517036437988}]
# ['nice sturdy use longterm storage container small bag']-- [{'label': 'neutral', 'score': 0.9998335838317871}]
# ['good originaltype container wooden handle smooth solid handle fit']-- [{'label': 'neutral', 'score': 0.9998425245285034}]
# ['excellent grill look nice problem really vacuum']-- [{'label': 'positive', 'score': 0.97084641456604}]
# ['nice large sturdy canvas tote lightweight comfortable']-- [{'label': 'neutral', 'score': 0.9991395473480225}]
# ['good quality good price love look feel pillow']-- [{'label': 'neutral', 'score': 0.9706259965896606}]
# ['ordered light blue arrived small opening yellow']-- [{'label': 'neutral', 'score': 0.9998607635498047}]
# ['purchased gift one two month']-- [{'label': 'neutral', 'score': 0.9998776912689209}]
# ['good price producti month used every']-- [{'label': 'neutral', 'score': 0.9998723268508911}]
# ['get shampoo conditioner want keep shower']-- [{'label': 'neutral', 'score': 0.9998427629470825}]
# ['minichair real chair full chair comfortable']-- [{'label': 'neutral', 'score': 0.9998531341552734}]
# ['happy purchase mattress month one']-- [{'label': 'neutral', 'score': 0.999854564666748}]
# ['work great keep light problem kind hard put']-- [{'label': 'positive', 'score': 0.7183247804641724}]
# ['bought son college love itvery good quality']-- [{'label': 'neutral', 'score': 0.8691156506538391}]
# ['terrible complete waste money whole lot say']-- [{'label': 'negative', 'score': 0.9624987840652466}]
# ['look nice bedroom material good large one']-- [{'label': 'neutral', 'score': 0.999568521976471}]
# ['easy put together look nice finish good large one']-- [{'label': 'neutral', 'score': 0.9970535039901733}]
# ['expected made real difference quality kitchenthis pretty']-- [{'label': 'positive', 'score': 0.9978487491607666}]
# ['im glad got set great deal price']-- [{'label': 'positive', 'score': 0.9996254444122314}]
# ['job adorable quality make nice addition kitchen']-- [{'label': 'neutral', 'score': 0.9374581575393677}]
# ['much work easy way make smoothie perfect']-- [{'label': 'neutral', 'score': 0.9992082715034485}]
# ['okay fit container well love blanket']-- [{'label': 'neutral', 'score': 0.9995622038841248}]
# ['far little plastic fine im sure well hold']-- [{'label': 'neutral', 'score': 0.9997778534889221}]
# ['nice gift friend love blanket']-- [{'label': 'neutral', 'score': 0.9996432065963745}]
# ['skinnier thought quality design lot product']-- [{'label': 'neutral', 'score': 0.748634934425354}]
# ['quick shipping excellent customer service great value moneythis great little']-- [{'label': 'positive', 'score': 0.9971494078636169}]
# ['work great design make easy hang nice size size']-- [{'label': 'positive', 'score': 0.831743061542511}]
# ['perfect work oven right height also love removable']-- [{'label': 'neutral', 'score': 0.9986864924430847}]
# ['service great cant wait try outvery good quality']-- [{'label': 'neutral', 'score': 0.6421185731887817}]
# ['arrived quickly perfect size long haul also large one']-- [{'label': 'neutral', 'score': 0.9959077835083008}]
# ['cheap china big deal little pricey']-- [{'label': 'neutral', 'score': 0.9993084669113159}]
# ['gave mother gift quality good really best one']-- [{'label': 'neutral', 'score': 0.9584510326385498}]
# ['great spice anything else good enoughnice sturdy functional']-- [{'label': 'neutral', 'score': 0.9988614320755005}]
# ['car smell different week snake oil']-- [{'label': 'neutral', 'score': 0.9998664855957031}]
# ['pillow cushion well constructed easily washed comfortable']-- [{'label': 'neutral', 'score': 0.9993684887886047}]
# ['havent used big one small one work great']-- [{'label': 'neutral', 'score': 0.9953600764274597}]
# ['take mystery meat finished cooking']-- [{'label': 'neutral', 'score': 0.9998801946640015}]
# ['nice organizer large enough utensil']-- [{'label': 'neutral', 'score': 0.9998542070388794}]
# ['work perfectly easy put art hang']-- [{'label': 'neutral', 'score': 0.9997853636741638}]
# ['great little rug id buy different color']-- [{'label': 'neutral', 'score': 0.9998564720153809}]
# ['hold gift wrap longer tube disappointing']-- [{'label': 'negative', 'score': 0.9922733902931213}]
# ['belt never last long enough seems work okay']-- [{'label': 'neutral', 'score': 0.9857439398765564}]
# ['great price less expensive renting great quality']-- [{'label': 'positive', 'score': 0.9218593239784241}]
# ['good price doesnt soften much washing']-- [{'label': 'positive', 'score': 0.9927065968513489}]
# ['love sheet go great star quilt']-- [{'label': 'neutral', 'score': 0.9997236132621765}]
# ['great mug bigger thought would']-- [{'label': 'neutral', 'score': 0.999441921710968}]
# ['gave gift daughter love']-- [{'label': 'neutral', 'score': 0.9994425177574158}]
# ['great great space saver laundry room']-- [{'label': 'neutral', 'score': 0.942021369934082}]
# ['flexible leading edge quite helpful condition']-- [{'label': 'positive', 'score': 0.9899358153343201}]
# ['bottom stay onzero customer service buy']-- [{'label': 'neutral', 'score': 0.9986259937286377}]
# ['nice elegant glass improve taste wine']-- [{'label': 'positive', 'score': 0.9976262450218201}]
# ['excellent product side sleeper perfect']-- [{'label': 'positive', 'score': 0.997791051864624}]
# ['oven make great place mat']-- [{'label': 'neutral', 'score': 0.9983021020889282}]
# ['love cute new bathroom']-- [{'label': 'neutral', 'score': 0.9992074370384216}]
# ['exactly pictured sturdy perfect baking cooking need']-- [{'label': 'neutral', 'score': 0.9997666478157043}]
# ['top notch artistry done bust grand jester studio']-- [{'label': 'neutral', 'score': 0.9998784065246582}]
# ['love get many comment spoon']-- [{'label': 'neutral', 'score': 0.9995697140693665}]
# ['expect table nice thanks']-- [{'label': 'neutral', 'score': 0.9858453273773193}]
# ['great product arrived time matched shower curtain perfectly']-- [{'label': 'positive', 'score': 0.6911444664001465}]
# ['nice secondary vacuum small apartment reaching tight area']-- [{'label': 'neutral', 'score': 0.9998816251754761}]
# ['good size good value money look great bar']-- [{'label': 'positive', 'score': 0.7199013233184814}]
# ['somewhat hard clean convenient hoped']-- [{'label': 'neutral', 'score': 0.9997639060020447}]
# ['work great battery candle brand']-- [{'label': 'neutral', 'score': 0.9944307208061218}]
# ['ok pillow kind hard firm soft']-- [{'label': 'neutral', 'score': 0.9997780919075012}]
# ['perfection beyond easy use minimal effort fast perfect froth']-- [{'label': 'neutral', 'score': 0.9980621933937073}]
# ['love item smile every time use']-- [{'label': 'neutral', 'score': 0.9997075200080872}]
# ['fleece blanket cozy warm exactly wanted']-- [{'label': 'neutral', 'score': 0.9996998310089111}]
# ['noticed today top id bubbling glass set']-- [{'label': 'neutral', 'score': 0.9998692274093628}]
# ['great weighing lb oz gram fast shipping']-- [{'label': 'neutral', 'score': 0.9998050332069397}]
# ['great order longer size']-- [{'label': 'neutral', 'score': 0.9998514652252197}]
# ['nice stick used almost every meal good pho']-- [{'label': 'neutral', 'score': 0.9998303651809692}]
# ['one best thing ever bought']-- [{'label': 'neutral', 'score': 0.99836665391922}]
# ['love small would love larger size']-- [{'label': 'neutral', 'score': 0.9998119473457336}]
# ['perfect candy buffet certainly multipurpose']-- [{'label': 'neutral', 'score': 0.9998714923858643}]
# ['work perfect use ev cord garage']-- [{'label': 'neutral', 'score': 0.99983811378479}]
# ['waste money broke one month']-- [{'label': 'negative', 'score': 0.9878203272819519}]
# ['little tacky shelf spare bathroom']-- [{'label': 'neutral', 'score': 0.9998131394386292}]
# ['help cool memory mattress little lot']-- [{'label': 'neutral', 'score': 0.9998067021369934}]
# ['perfect wish would ordered earlier']-- [{'label': 'neutral', 'score': 0.9998486042022705}]
# ['excellent packaging fast shipping super quality right price']-- [{'label': 'positive', 'score': 0.9951851963996887}]
# ['good mix favorite still goloka nag champa']-- [{'label': 'neutral', 'score': 0.9997642636299133}]
# ['bride wanted came nice engraving']-- [{'label': 'neutral', 'score': 0.9998472929000854}]
# ['color slightly different gotthe website picture look better']-- [{'label': 'positive', 'score': 0.9806041717529297}]
# ['really great soft warm love feel blanket']-- [{'label': 'neutral', 'score': 0.8506242632865906}]
# ['less year old ive mine month']-- [{'label': 'neutral', 'score': 0.9998699426651001}]
# ['pint pint also pint']-- [{'label': 'neutral', 'score': 0.9998781681060791}]
# ['perfect needed love look feel pillow']-- [{'label': 'neutral', 'score': 0.99979168176651}]
# ['bought pick old mattress nice piece equipment']-- [{'label': 'neutral', 'score': 0.9998428821563721}]
# ['plastic ring either gone destroyed piece keep old one gift']-- [{'label': 'neutral', 'score': 0.9997199177742004}]
# ['nice trouble look finish bit thin best quality']-- [{'label': 'neutral', 'score': 0.9960596561431885}]
# ['great seller item like itgreat quality needed kitchen']-- [{'label': 'neutral', 'score': 0.9863052368164062}]
# ['cute go big small']-- [{'label': 'neutral', 'score': 0.9998231530189514}]
# ['look high end feel nice problem kind hard put']-- [{'label': 'positive', 'score': 0.8400285840034485}]
# ['mug nice love look feel size']-- [{'label': 'neutral', 'score': 0.9995635151863098}]
# ['work really well look great material good large one']-- [{'label': 'neutral', 'score': 0.9193060398101807}]
# ['ordered gift arrived time keep review next']-- [{'label': 'neutral', 'score': 0.9998143315315247}]
# ['beautiful calming light sure love blanket']-- [{'label': 'neutral', 'score': 0.9985894560813904}]
# ['like clock although design flaw little hard read']-- [{'label': 'neutral', 'score': 0.9997091889381409}]
# ['exactly advertised better quality original love blanket']-- [{'label': 'positive', 'score': 0.9986510872840881}]
# ['perfect solution sorting mess tool also love removable']-- [{'label': 'neutral', 'score': 0.9985843896865845}]
# ['cute item going go wide wooden leg nice dinner table']-- [{'label': 'neutral', 'score': 0.9998416900634766}]
# ['beautious perfect wall clock good size look great']-- [{'label': 'neutral', 'score': 0.924175500869751}]
# ['ok buying second seti love container work well look']-- [{'label': 'positive', 'score': 0.7902776002883911}]
# ['great comforter especially go keep shelf order']-- [{'label': 'neutral', 'score': 0.9996331930160522}]
# ['nice fit right quality good reason']-- [{'label': 'neutral', 'score': 0.9955684542655945}]
# ['nice mug long fit nicely shelf']-- [{'label': 'neutral', 'score': 0.9997736811637878}]
# ['easy assemble arrived time described husband']-- [{'label': 'neutral', 'score': 0.9998230338096619}]
# ['bought one daughter comfortable also love way bed']-- [{'label': 'neutral', 'score': 0.9997895359992981}]
# ['wife love packed piece perfect']-- [{'label': 'neutral', 'score': 0.9989487528800964}]
# ['love crockpots perfect wide variety container']-- [{'label': 'neutral', 'score': 0.9998225569725037}]
# ['hang look nice ive also used hour']-- [{'label': 'neutral', 'score': 0.9913039207458496}]
# ['using second set glass thought would nice addition kitchen']-- [{'label': 'neutral', 'score': 0.9882320761680603}]
# ['big mirror fit perfectly cabinet ive also used year']-- [{'label': 'neutral', 'score': 0.9997522234916687}]
# ['pretty good quite piece small would recommend']-- [{'label': 'neutral', 'score': 0.9924240112304688}]
# ['second one bought nice piece equipment']-- [{'label': 'neutral', 'score': 0.9998449087142944}]
# ['perfect size hanging wreath easy use efficient way make small wreath']-- [{'label': 'neutral', 'score': 0.997654139995575}]
# ['adore bowl cant wait make next batch cold drinksthis']-- [{'label': 'neutral', 'score': 0.9998555183410645}]
# ['work great also use measuring cup measuring cupcake']-- [{'label': 'neutral', 'score': 0.9998717308044434}]
# ['nice fit hand love feel fabric color']-- [{'label': 'neutral', 'score': 0.9997180104255676}]
# ['great price month used every']-- [{'label': 'neutral', 'score': 0.9998481273651123}]
# ['bought bottling wine love also like fact']-- [{'label': 'neutral', 'score': 0.9997406601905823}]
# ['good padding nice quality love feel fabric would buy']-- [{'label': 'neutral', 'score': 0.7030800580978394}]
# ['love popcorn machine love popcorn keep popcorn one']-- [{'label': 'neutral', 'score': 0.9998113512992859}]
# ['nice size container little small cup teavery pretty']-- [{'label': 'neutral', 'score': 0.9998592138290405}]
# ['much easier use cant go wrong product keep review next']-- [{'label': 'neutral', 'score': 0.999305248260498}]
# ['great opener look nice countertop keep opener drawer']-- [{'label': 'neutral', 'score': 0.9913425445556641}]
# ['love wish handle wide good quality']-- [{'label': 'neutral', 'score': 0.9925368428230286}]
# ['seems defective seal way fix throw container']-- [{'label': 'negative', 'score': 0.9862548112869263}]
# ['work great boy love fact cant turn']-- [{'label': 'neutral', 'score': 0.999806821346283}]
# ['sturdy snap place comfortable reason gave']-- [{'label': 'neutral', 'score': 0.9973760843276978}]
# ['worked well problem small one']-- [{'label': 'positive', 'score': 0.7374400496482849}]
# ['great color feel soft great price would recommend']-- [{'label': 'positive', 'score': 0.747678279876709}]
# ['small work dont lot space']-- [{'label': 'neutral', 'score': 0.9998513460159302}]
# ['burn hell hand doesnt work high temp']-- [{'label': 'neutral', 'score': 0.9998255372047424}]
# ['work fast replaced one broke']-- [{'label': 'neutral', 'score': 0.9956510663032532}]
# ['shower curtain beautiful nice fabric look great bathroom']-- [{'label': 'neutral', 'score': 0.9922772645950317}]
# ['use work staff holding well']-- [{'label': 'positive', 'score': 0.9856353998184204}]
# ['great mug husband say one favorite']-- [{'label': 'neutral', 'score': 0.9996582269668579}]
# ['worked great small space closet']-- [{'label': 'neutral', 'score': 0.9997312426567078}]
# ['gift dont know beautiful']-- [{'label': 'neutral', 'score': 0.9997960925102234}]
# ['product actually work tried use definitely difference']-- [{'label': 'neutral', 'score': 0.9992852807044983}]
# ['happy quality merchandise speedy delivery']-- [{'label': 'positive', 'score': 0.9975669384002686}]
# ['american made love need matching measuring cup']-- [{'label': 'neutral', 'score': 0.9998530149459839}]
# ['enough whole pie would need two three set']-- [{'label': 'neutral', 'score': 0.9998650550842285}]
# ['impressed quality great size bag durable']-- [{'label': 'positive', 'score': 0.8348001837730408}]
# ['suppose hot water flash']-- [{'label': 'neutral', 'score': 0.9998825788497925}]
# ['fantastic goblet store lot fluid like wine beer']-- [{'label': 'neutral', 'score': 0.9998657703399658}]
# ['doesnt get warm even sitting hour']-- [{'label': 'neutral', 'score': 0.9996376037597656}]
# ['cant believe low price quality love']-- [{'label': 'neutral', 'score': 0.9172766804695129}]
# ['reorder rated whwn originally purchase']-- [{'label': 'neutral', 'score': 0.9998781681060791}]
# ['make good cup coffee take cup']-- [{'label': 'neutral', 'score': 0.9998688697814941}]
# ['ordered husbandhe love setespecially noodle strainer']-- [{'label': 'neutral', 'score': 0.9998421669006348}]
# ['plastic thread socket bulb sent fit']-- [{'label': 'neutral', 'score': 0.9998145699501038}]
# ['nice havent totally unpacked yet gift styrofoam place']-- [{'label': 'neutral', 'score': 0.9997931122779846}]
# ['dont last long pull along otherwise ok']-- [{'label': 'neutral', 'score': 0.9997743964195251}]
# ['exactly looking love clear']-- [{'label': 'neutral', 'score': 0.9997122883796692}]
# ['great toilet brush holder sleek design appear well made']-- [{'label': 'positive', 'score': 0.9951332211494446}]
# ['excellent service arrived quickly promised lovely lamp']-- [{'label': 'positive', 'score': 0.998598039150238}]
# ['loved small little cookie cutter job perfectly']-- [{'label': 'neutral', 'score': 0.8283977508544922}]
# ['make keeping track shoe easier floor visible']-- [{'label': 'positive', 'score': 0.5405820608139038}]
# ['wonderful product shipped promptly ordered ten set gift']-- [{'label': 'neutral', 'score': 0.9981244206428528}]
# ['slow toasting rye bread becomes rock hard toasted']-- [{'label': 'negative', 'score': 0.8482053279876709}]
# ['find bit soft overall ok']-- [{'label': 'negative', 'score': 0.9751560091972351}]
# ['bought one corner broken']-- [{'label': 'neutral', 'score': 0.9872950911521912}]
# ['want perfect pastacerealice creamsoup bowl ever perfect size cereal']-- [{'label': 'neutral', 'score': 0.9995874762535095}]
# ['love blue air product filter cover awesome']-- [{'label': 'neutral', 'score': 0.9990984201431274}]
# ['love good quality nice soft night light noise variation']-- [{'label': 'neutral', 'score': 0.960824191570282}]
# ['worked ok one time fell apart became unusable']-- [{'label': 'negative', 'score': 0.9868757724761963}]
# ['good strong suction vacuume world good carpet also']-- [{'label': 'positive', 'score': 0.9990365505218506}]
# ['nice floral dead heading watering']-- [{'label': 'neutral', 'score': 0.9998449087142944}]
# ['lghts work beautifully bright']-- [{'label': 'neutral', 'score': 0.9350535869598389}]
# ['worked rum infused chocolate covered strawberry molded chocolate heart']-- [{'label': 'neutral', 'score': 0.9998772144317627}]
# ['shell beautiful im looking thanks']-- [{'label': 'neutral', 'score': 0.9968591928482056}]
# ['good quality great price tad loose mattress']-- [{'label': 'neutral', 'score': 0.9769791960716248}]
# ['sturdy great addition eat breakfast nook']-- [{'label': 'neutral', 'score': 0.9933509230613708}]
# ['classic sturdy functional perfect keeping honey room temperature']-- [{'label': 'neutral', 'score': 0.9941456317901611}]
# ['wonderful great size throw dishwasher area great']-- [{'label': 'neutral', 'score': 0.6399468779563904}]
# ['one came broken handle broken piece']-- [{'label': 'neutral', 'score': 0.8386286497116089}]
# ['sturdy hold camis make easy access']-- [{'label': 'neutral', 'score': 0.9982103109359741}]
# ['beautiful shower curtain wanted look good bathroom']-- [{'label': 'neutral', 'score': 0.998683512210846}]
# ['used container couple week really love one']-- [{'label': 'neutral', 'score': 0.9965527057647705}]
# ['love way top hold suction cup also love suction cup']-- [{'label': 'neutral', 'score': 0.9998801946640015}]
# ['love candleshave ordered morealso candle burn couple week']-- [{'label': 'neutral', 'score': 0.9998487234115601}]
# ['used white elephant thin liking']-- [{'label': 'neutral', 'score': 0.9998503923416138}]
# ['daughter love month great']-- [{'label': 'neutral', 'score': 0.9472862482070923}]
# ['single cup coffee feel coffee taste fresher coffee taste lighter']-- [{'label': 'neutral', 'score': 0.9319154620170593}]
# ['expected old one keep future']-- [{'label': 'neutral', 'score': 0.9997523427009583}]
# ['unpacked used soon arrived little surprised well one']-- [{'label': 'neutral', 'score': 0.840355634689331}]
# ['flimsy blackout curtain easy task put together also dimension']-- [{'label': 'neutral', 'score': 0.9994818568229675}]
# ['standard christmas present friend love reason gave']-- [{'label': 'neutral', 'score': 0.9997842907905579}]
# ['look fantastic guest room problem really vacuum']-- [{'label': 'positive', 'score': 0.5784383416175842}]
# ['easy put love look feel pillow']-- [{'label': 'neutral', 'score': 0.9998332262039185}]
# ['absolutely love month great']-- [{'label': 'neutral', 'score': 0.8930615186691284}]
# ['fit oz ozark love fact come small']-- [{'label': 'neutral', 'score': 0.9998657703399658}]
# ['amazing product look amazing kitchen definitely buy againvery pretty']-- [{'label': 'positive', 'score': 0.9811918139457703}]
# ['perfect size egg couple reason need lot egg white']-- [{'label': 'neutral', 'score': 0.9998676776885986}]
# ['great straw durable last long time reason gave']-- [{'label': 'positive', 'score': 0.93426513671875}]
# ['job thinner professional blender say pretty good']-- [{'label': 'positive', 'score': 0.9973970651626587}]
# ['nicely made great keeping open space shelf well made']-- [{'label': 'positive', 'score': 0.9992770552635193}]
# ['fit well seems last long time good quality']-- [{'label': 'positive', 'score': 0.9959514141082764}]
# ['love perfect need ive mine couple year']-- [{'label': 'neutral', 'score': 0.9998254179954529}]
# ['look pretty see wear tear overall right size']-- [{'label': 'neutral', 'score': 0.6576902866363525}]
# ['excellent product second love look feel pillow']-- [{'label': 'positive', 'score': 0.9782382249832153}]
# ['ergonomically correct problem really']-- [{'label': 'neutral', 'score': 0.999599277973175}]
# ['mom love perfect summervery good qualitynice sturdy sturdy']-- [{'label': 'neutral', 'score': 0.986702024936676}]
# ['tiny spatula unless using professional spatula need make sure']-- [{'label': 'neutral', 'score': 0.9998496770858765}]
# ['purchased yearold daughter arthritis hand']-- [{'label': 'neutral', 'score': 0.9998583793640137}]
# ['easy set sturdy easy clean purchasing morevery pretty']-- [{'label': 'neutral', 'score': 0.9977329969406128}]
# ['still good product reading reviewsvery good qualitynice sturdy functional']-- [{'label': 'positive', 'score': 0.6433842182159424}]
# ['use bag store container thick sturdy easy']-- [{'label': 'neutral', 'score': 0.9997972846031189}]
# ['thought would good addition kitchen also large kitchen']-- [{'label': 'neutral', 'score': 0.9977109432220459}]
# ['complement different color scheme vibrant comfortable']-- [{'label': 'neutral', 'score': 0.9998559951782227}]
# ['softer expensive expensive expensive model im sure']-- [{'label': 'neutral', 'score': 0.9998028874397278}]
# ['put bottle wine freezer still fresh one']-- [{'label': 'neutral', 'score': 0.9998674392700195}]
# ['small compact travel mug design design travel mug']-- [{'label': 'neutral', 'score': 0.9998732805252075}]
# ['work like charm item look great material good large one']-- [{'label': 'neutral', 'score': 0.9933207631111145}]
# ['love use daily best keep reviewvery pretty']-- [{'label': 'neutral', 'score': 0.9996576309204102}]
# ['item exactly described arrived good seal dimension']-- [{'label': 'neutral', 'score': 0.9996901750564575}]
# ['great pug dog treat good size lid strong enough']-- [{'label': 'neutral', 'score': 0.9955917000770569}]
# ['fit husband bed small would order one']-- [{'label': 'neutral', 'score': 0.9998621940612793}]
# ['wanted quality wanted dimension']-- [{'label': 'neutral', 'score': 0.9997854828834534}]
# ['comfortable help wrist problem really vacuum']-- [{'label': 'neutral', 'score': 0.9379987120628357}]
# ['dont waste time buying set thin need cleaned every']-- [{'label': 'neutral', 'score': 0.9997784495353699}]
# ['wish bought sooner great product price']-- [{'label': 'positive', 'score': 0.998887836933136}]
# ['wish thicker cute polka dot pretty much disappear baking']-- [{'label': 'neutral', 'score': 0.999725878238678}]
# ['hook great hanging star ceiling great price']-- [{'label': 'positive', 'score': 0.7974077463150024}]
# ['returned exchanged twice base broken every time']-- [{'label': 'neutral', 'score': 0.9998737573623657}]
# ['knife sharp careful worked perfect needed']-- [{'label': 'neutral', 'score': 0.9995935559272766}]
# ['nice travel taking italy ice rather scarce']-- [{'label': 'negative', 'score': 0.9123570919036865}]
# ['handle bit thickerstronger great product']-- [{'label': 'positive', 'score': 0.9855566620826721}]
# ['buy quit working less month purchased']-- [{'label': 'neutral', 'score': 0.9977130889892578}]
# ['sturdy expected wobble job though']-- [{'label': 'negative', 'score': 0.9973405003547668}]
# ['blue color much better picture good price quality']-- [{'label': 'positive', 'score': 0.9943055510520935}]
# ['knob end rod broke good quality product']-- [{'label': 'positive', 'score': 0.9392197132110596}]
# ['hold clothes yellow stuff doesnt rub good hangar']-- [{'label': 'negative', 'score': 0.7169172167778015}]
# ['little shorter expected try next christmas']-- [{'label': 'neutral', 'score': 0.9998086094856262}]
# ['love sheet soft cotton feel fit king waterbed']-- [{'label': 'neutral', 'score': 0.999850869178772}]
# ['others mentioned cord kinda small hose kinda stiff']-- [{'label': 'neutral', 'score': 0.999679684638977}]
# ['got daughter new place seems love']-- [{'label': 'neutral', 'score': 0.9948375821113586}]
# ['really fun alice wonderland themed party']-- [{'label': 'neutral', 'score': 0.999762237071991}]
# ['beautiful table runner look great antique table']-- [{'label': 'neutral', 'score': 0.9981098175048828}]
# ['worked expected good price much say balloon weight']-- [{'label': 'positive', 'score': 0.9937341809272766}]
# ['nice easy assemble serf purpose functional aesthetically']-- [{'label': 'neutral', 'score': 0.9996114373207092}]
# ['useful attractive made old knife obsolete']-- [{'label': 'negative', 'score': 0.9868331551551819}]
# ['work great less shark brand wiil bought']-- [{'label': 'positive', 'score': 0.9506563544273376}]
# ['exactly advertised get moldy easy clean']-- [{'label': 'neutral', 'score': 0.9979287385940552}]
# ['nice design great speed worked excellent home made tamale']-- [{'label': 'positive', 'score': 0.9741539359092712}]
# ['smell good broken glass cracked bad']-- [{'label': 'neutral', 'score': 0.7902770638465881}]
# ['sent soap fish looked nothing like picture cattie']-- [{'label': 'neutral', 'score': 0.9995686411857605}]
# ['great product job well holding lunch several day week']-- [{'label': 'positive', 'score': 0.9995172023773193}]
# ['cute lunchbox great preschooler fit plenty food easy clean']-- [{'label': 'neutral', 'score': 0.9990241527557373}]
# ['nice quality bought used solo campfire stove']-- [{'label': 'neutral', 'score': 0.9997732043266296}]
# ['cant beat time tested design easy installation highly functional priced right']-- [{'label': 'neutral', 'score': 0.9197192788124084}]
# ['term overall durability theyre great scratch easily']-- [{'label': 'positive', 'score': 0.9701216816902161}]
# ['far good weird smell unlike many plastic liner']-- [{'label': 'neutral', 'score': 0.9952899217605591}]
# ['fantastic design debris fall end designed']-- [{'label': 'neutral', 'score': 0.9998161196708679}]
# ['nice size fit perfectly love added organization provide']-- [{'label': 'positive', 'score': 0.9721664190292358}]
# ['use pot everything second purchase']-- [{'label': 'neutral', 'score': 0.9998836517333984}]
# ['pleased product arrived timely manner exactly shown']-- [{'label': 'neutral', 'score': 0.8008670806884766}]
# ['great mudrooma towel rack wonderful project']-- [{'label': 'neutral', 'score': 0.9942097663879395}]
# ['sooooooo cute love adorable well made totally worth price']-- [{'label': 'neutral', 'score': 0.9791738986968994}]
# ['got gift son']-- [{'label': 'neutral', 'score': 0.9998403787612915}]
# ['hygienic great look else want toilet brush']-- [{'label': 'neutral', 'score': 0.9996080994606018}]
# ['bar rimming salt margarita look sleek']-- [{'label': 'neutral', 'score': 0.9037601947784424}]
# ['returned thought ordering bed trundle']-- [{'label': 'neutral', 'score': 0.999836802482605}]
# ['clock large easy read inexpensive get job done']-- [{'label': 'neutral', 'score': 0.9979658126831055}]
# ['great tool knife sharp purchased new']-- [{'label': 'neutral', 'score': 0.999586284160614}]
# ['super cute great price blue white']-- [{'label': 'neutral', 'score': 0.9991975426673889}]
# ['bought gift daughter seems great buy']-- [{'label': 'positive', 'score': 0.9602054357528687}]
# ['good buy price problem kind hard put']-- [{'label': 'neutral', 'score': 0.725338876247406}]
# ['doesnt fit queen bed material thick thin queen bed']-- [{'label': 'neutral', 'score': 0.9998742341995239}]
# ['great product corelle yearswonderful product']-- [{'label': 'positive', 'score': 0.7587370872497559}]
# ['keep cold drink cold hot drink hot cold drink hot reason gave']-- [{'label': 'neutral', 'score': 0.9998685121536255}]
# ['exactly decribed shown picture actual dimension']-- [{'label': 'neutral', 'score': 0.9998756647109985}]
# ['ottoman look nice comfortable look nice countertop']-- [{'label': 'neutral', 'score': 0.9990863800048828}]
# ['glass wonderful color vibrant design nice touch']-- [{'label': 'neutral', 'score': 0.9156439304351807}]
# ['bought gift daughter loved great']-- [{'label': 'neutral', 'score': 0.9928047060966492}]
# ['great product service use everydayvery comfortable love itvery pretty']-- [{'label': 'neutral', 'score': 0.9263899922370911}]
# ['curtain werent wide expected expecting tighter curtain']-- [{'label': 'neutral', 'score': 0.9986227750778198}]
# ['easy use pie edge little thin keep mind making']-- [{'label': 'neutral', 'score': 0.9998528957366943}]
# ['totally work use everyday easy clean']-- [{'label': 'neutral', 'score': 0.999755322933197}]
# ['color good look good material good quality good']-- [{'label': 'neutral', 'score': 0.9992738366127014}]
# ['amazing look wall keep long time']-- [{'label': 'neutral', 'score': 0.9973904490470886}]
# ['knife arent nice theyre also sharp blade sharp']-- [{'label': 'neutral', 'score': 0.9996947050094604}]
# ['love set look great color vibrant large collection']-- [{'label': 'neutral', 'score': 0.9957097768783569}]
# ['great cupcake holder looked nice sturdy instruction little misleading']-- [{'label': 'neutral', 'score': 0.9013360142707825}]
# ['wife making cooky last two year shes happy way shes']-- [{'label': 'positive', 'score': 0.6364708542823792}]
# ['pillow excessively firm older version pillow little larger']-- [{'label': 'neutral', 'score': 0.9997625946998596}]
# ['grow spice herb needed kitchen']-- [{'label': 'neutral', 'score': 0.9998713731765747}]
# ['high quality work well solid material problem really vacuum']-- [{'label': 'neutral', 'score': 0.9931372404098511}]
# ['handled heavy pan without tipping problem kind hard put']-- [{'label': 'neutral', 'score': 0.9997859597206116}]
# ['look nice small likingvery good qualitynice sturdy functional']-- [{'label': 'neutral', 'score': 0.9989979863166809}]
# ['stunning clean modern month']-- [{'label': 'neutral', 'score': 0.9992789626121521}]
# ['really like item month']-- [{'label': 'neutral', 'score': 0.9998654127120972}]
# ['perfect white desk love look feel chair']-- [{'label': 'neutral', 'score': 0.9998149275779724}]
# ['gorgeous industrial feel easy use problem really']-- [{'label': 'neutral', 'score': 0.6091516613960266}]
# ['exactly described purchased gift recipient loved']-- [{'label': 'neutral', 'score': 0.9998501539230347}]
# ['nice size nice quality keep next couple']-- [{'label': 'neutral', 'score': 0.9876924157142639}]
# ['knife look well kitchen problem really strong one']-- [{'label': 'positive', 'score': 0.9686965346336365}]
# ['pretty size perfect thick enough hold small person']-- [{'label': 'neutral', 'score': 0.9998314380645752}]
# ['used mattress kept sheet comfortable also mattress']-- [{'label': 'neutral', 'score': 0.9996949434280396}]
# ['comfortable made lot use ive mine couple']-- [{'label': 'neutral', 'score': 0.9997990727424622}]
# ['far thing great addition kitchen large kitchen']-- [{'label': 'neutral', 'score': 0.9970614314079285}]
# ['fit well thick one still nice one']-- [{'label': 'neutral', 'score': 0.9978365302085876}]
# ['icetray really easyrelease design make work']-- [{'label': 'neutral', 'score': 0.9927339553833008}]
# ['scale accurate bit large scale']-- [{'label': 'neutral', 'score': 0.999836802482605}]
# ['use laundry good size couple']-- [{'label': 'neutral', 'score': 0.9998708963394165}]
# ['sheet thin wide opening purchasing different size']-- [{'label': 'neutral', 'score': 0.9998657703399658}]
# ['exactly needed problem small one']-- [{'label': 'neutral', 'score': 0.9998313188552856}]
# ['loved stopped working within week thing turn']-- [{'label': 'negative', 'score': 0.629910409450531}]
# ['love wife good quality']-- [{'label': 'neutral', 'score': 0.9982832670211792}]
# ['make sure followthe direction easy follow keep review']-- [{'label': 'neutral', 'score': 0.999800980091095}]
# ['cushion work well intended reason gave']-- [{'label': 'positive', 'score': 0.9986672401428223}]
# ['doesnt last long burn long wont float']-- [{'label': 'neutral', 'score': 0.9998230338096619}]
# ['use make beer chicken smoker clean easily']-- [{'label': 'neutral', 'score': 0.9997808337211609}]
# ['soft soft soft love would order without hesitation']-- [{'label': 'neutral', 'score': 0.9995922446250916}]
# ['perfect small scale easy use compact size make convenient travel']-- [{'label': 'neutral', 'score': 0.8232613801956177}]
# ['love pitcher perfect tea doesnt drip everything']-- [{'label': 'neutral', 'score': 0.9998553991317749}]
# ['every bit good name brand hesitate get']-- [{'label': 'neutral', 'score': 0.9995688796043396}]
# ['perfect size kitchen easy assemble happy cart']-- [{'label': 'neutral', 'score': 0.9998190999031067}]
# ['didnt really help make difference must time new robot']-- [{'label': 'neutral', 'score': 0.9985455274581909}]
# ['hook gorgeous really add elegant touch shower curtain']-- [{'label': 'neutral', 'score': 0.9972831010818481}]
# ['love color love lightweight bowl much larger expected']-- [{'label': 'neutral', 'score': 0.9964655637741089}]
# ['item bulky small apartment counter top work like charm']-- [{'label': 'neutral', 'score': 0.9998646974563599}]
# ['love love love coffee maker perfect size rv']-- [{'label': 'neutral', 'score': 0.9998089671134949}]
# ['work well even partially submerged make frothing easy beginner like']-- [{'label': 'positive', 'score': 0.9371448755264282}]
# ['went together ok look good corner color dark']-- [{'label': 'neutral', 'score': 0.9992713332176208}]
# ['rarely use ac live somewhere humidity']-- [{'label': 'neutral', 'score': 0.9998843669891357}]
# ['gift husband sharpened every knife house work well problem']-- [{'label': 'positive', 'score': 0.6789419054985046}]
# ['nice towel absorbs well getting ready see come gray']-- [{'label': 'neutral', 'score': 0.9763525128364563}]
# ['nice product much experience thing roller awesome']-- [{'label': 'positive', 'score': 0.9843621253967285}]
# ['plastic little flimsy hold many photo keep safe']-- [{'label': 'neutral', 'score': 0.9998342990875244}]
# ['knife sharpener work really well also sharpen sewing scissors']-- [{'label': 'positive', 'score': 0.6646149158477783}]
# ['product sturdy nice design last last']-- [{'label': 'neutral', 'score': 0.7087646722793579}]
# ['decent price using behind love seatso work']-- [{'label': 'neutral', 'score': 0.9998654127120972}]
# ['definitely water proof worth price keep dust dirt away']-- [{'label': 'neutral', 'score': 0.9995989203453064}]
# ['nice careful handling edge crack easily']-- [{'label': 'neutral', 'score': 0.9734521508216858}]
# ['mismatched header v bed frame worked great recommended since']-- [{'label': 'positive', 'score': 0.999338686466217}]
# ['gift daughter said really work well']-- [{'label': 'positive', 'score': 0.9986332058906555}]
# ['kind cheap really thin metal trick exactly youd expect']-- [{'label': 'neutral', 'score': 0.9997841715812683}]
# ['love product wish built razor cutting otherwise im happy']-- [{'label': 'positive', 'score': 0.5855261087417603}]
# ['cute granddaughter play kitchen set']-- [{'label': 'neutral', 'score': 0.9998748302459717}]
# ['gift granddaughter saw mine love']-- [{'label': 'neutral', 'score': 0.9994475245475769}]
# ['worked great skin hair definitely recommend others']-- [{'label': 'neutral', 'score': 0.7628006339073181}]
# ['simply put fantastic happy purchase thank']-- [{'label': 'positive', 'score': 0.9989911913871765}]
# ...
# ['bought mustarddull yellow one good one used twice one dishwasher one dishwasher one sink still look good think going last long time im looking forward using salad hope last long time wish']-- [{'label': 'positive', 'score': 0.9965977072715759}]
# ['couple isi whip cream charger past mainly used isi cartridge decided try purist cartridge big price discount based cartridge used far weve perfection operation isi cartridge sometimes difficult puncture requiring plier protective wrap tighten cap enough penetrate cartridge far purist cartridge penetrated easily fully charged dispenser']-- [{'label': 'neutral', 'score': 0.9993559718132019}]
# ['sloppy fit jug electric motor necessating hold whole thing hand turned poor seal jar cap caused spillage mess variable rheostat couldnt start slowly avoid jump liquid jar believe next time go rifle range ill take thing satisfaction killing']-- [{'label': 'negative', 'score': 0.9941102862358093}]
# ['bag arrived thought mistake bag looked small opened still thought going fit anything delight huge exactly needed im storing bed sheet fitted flat dog many sheet couch one clothing dont realize deep zip start packing easily fit bed happy']-- [{'label': 'neutral', 'score': 0.9996809959411621}]
# ['easy put together anyone like shelf build high low want couldnt build way cabinet used rest material built another two tier shelf son closet far good three kid plus husband shoe galore definitely help keep shoe neat organized']-- [{'label': 'neutral', 'score': 0.9985507130622864}]
# ['bought replace stylish set bought different manufacturer shortly got married far durable best big cant fit dish washer corelle made plate material year expect last long parent inlaws set corelle may trendy design job well']-- [{'label': 'positive', 'score': 0.9958415627479553}]
# ['want reach last little bit thats waaaay bottom jar norpro silicone jaricing spatula cleanly scrape remaining morsel even narrow jar slim size far icing concerned havent easier time frosting cake cupcake since purchasing product smooth application manoeuverable fit right hole angel food cake great smoothing frosting creating peak swirl']-- [{'label': 'neutral', 'score': 0.9989855885505676}]
# ['lid little tight bottom nice bonus like extra space open lid get first drink lid bit small use size glass fit lid bit small hang wall lid lightweight comfortable cant imagine hanging']-- [{'label': 'neutral', 'score': 0.9370829463005066}]
# ['wonderful hold lot finish good large one small one happy purchasethis great fan quiet fan noise fan quiet fan noise keep buying amazoncom againive year love']-- [{'label': 'positive', 'score': 0.9269986152648926}]
# ['first saw amazon thought little cheaper one plastic solid easy clean thing didnt like lid bottom problem place hand push plastic right top lid use little force']-- [{'label': 'neutral', 'score': 0.9980619549751282}]
# ['love opening little wide im happy purchase bottom deep also like fact side adjustable used variety setting great producti bought put closet store thing didnt realize much space would hold put']-- [{'label': 'positive', 'score': 0.6733839511871338}]
# ['really like product love look feel size appearance great happy purchasethis great fan quiet job perfectly wish bit thicker thing would change order red one bit big put side']-- [{'label': 'positive', 'score': 0.9917995929718018}]
# ['great desk nice addition kitchenthis pretty good quality measuring cup using instruction class cup well made handle bit large liking would definitely buy kitchen little heavier expected big deal']-- [{'label': 'positive', 'score': 0.9933552742004395}]
# ['positively love ottomani purchased store extra blanket pillowit delivered time screw little legsthe top hinge stay open getting anything outi setting front master bedroom window sit put shoe boot etc plan buying another ottoman guest bedroom store beddingthis ottoman look good enough livingroom']-- [{'label': 'neutral', 'score': 0.9980748891830444}]
# ['dont rest certainly seems like drawer full clothes kitchen towel sock underwear etc take odor time little bag take smell within week amazing successful prefer using natural unscented product cleaning bathing laundry etc little gem definitely fill bill destroying annoying odor another plus recharged placing sun prescribed time']-- [{'label': 'positive', 'score': 0.9799624681472778}]
# ['looking less expensive cookware nuwave offer great buy reasonably priced use barkeep friend handwash dishwasher believe properly take care cookware simply last longer look really nice exactly wanted digging thru buyer complaint exaggerated others helpful far care instruction recommend looking induction ready cookware']-- [{'label': 'positive', 'score': 0.9699923992156982}]
# ['ive kind sheet marginal top line favorite yummy sheet im using august hotter set thread count sateen sheet dont pill fit mattress well sure theyd fit anything bigger stitching hem perfect really affordable given expensive sheet day especially king im buying wish color rose perhaps']-- [{'label': 'neutral', 'score': 0.7845463156700134}]
# ['make good french fry seem provide heat frying requires higher heat stove get max f take minute appreciate product magnetic cord safety tip dont dump frozen fry directly fryer avoid splatter throw air fryer dry moisture minute deep fry come well']-- [{'label': 'neutral', 'score': 0.9998229146003723}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-88a16558d1fd> in <cell line: 1>()
#       1 for row in range(len(df['text_'])):
#       2   text=[df['text_'].iloc[row]]
# ----> 3   print(f"{text}-- {pipe(text)}")
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py in __call__(self, inputs, **kwargs)
#     157         """
#     158         inputs = (inputs,)
# --> 159         result = super().__call__(*inputs, **kwargs)
#     160         # TODO try and retrieve it in a nicer way from _sanitize_parameters.
#     161         _legacy = "top_k" not in kwargs
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1281                     inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1282                 )
# -> 1283                 outputs = list(final_iterator)
#    1284                 return outputs
#    1285             else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     122
#     123         # We're out of items within a batch
# --> 124         item = next(self.iterator)
#     125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     123         # We're out of items within a batch
#     124         item = next(self.iterator)
# --> 125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#     127         if self.loader_batch_size is not None:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1207                 with inference_context():
#    1208                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1209                     model_outputs = self._forward(model_inputs, **forward_params)
#    1210                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1211             else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py in _forward(self, model_inputs)
#     188         if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     189             model_inputs["use_cache"] = False
# --> 190         return self.model(**model_inputs)
#     191
#     192     def postprocess(self, model_outputs, function_to_apply=None, top_k=1, _legacy=True):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1316         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1317
# -> 1318         outputs = self.roberta(
#    1319             input_ids,
#    1320             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     974         head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     975
# --> 976         encoder_outputs = self.encoder(
#     977             embedding_output,
#     978             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     629                 )
#     630             else:
# --> 631                 layer_outputs = layer_module(
#     632                     hidden_states,
#     633                     attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     560             present_key_value = present_key_value + cross_attn_present_key_value
#     561
# --> 562         layer_output = apply_chunking_to_forward(
#     563             self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     564         )
#
# /usr/local/lib/python3.10/dist-packages/transformers/pytorch_utils.py in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     246         return torch.cat(output_chunks, dim=chunk_dim)
#     247
# --> 248     return forward_fn(*input_tensors)
#     249
#     250
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/roberta/modeling_roberta.py in feed_forward_chunk(self, attention_output)
#     573     def feed_forward_chunk(self, attention_output):
#     574         intermediate_output = self.intermediate(attention_output)
# --> 575         layer_output = self.output(intermediate_output, attention_output)
#     576         return layer_output
#     577
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/roberta/modeling_roberta.py in forward(self, hidden_states, input_tensor)
#     484
#     485     def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 486         hidden_states = self.dense(hidden_states)
#     487         hidden_states = self.dropout(hidden_states)
#     488         hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
pipe(['this is a good movie'])
# Out:
# [{'label': 'neutral', 'score': 0.65187007188797}]

# %%
# prompt: how to access the label in the output

for row in range(100):
  text=[df['text_'].iloc[row]]
  result = pipe(text)

  # Access the label
  label = result[0]['label']
  print(f"Label for text {row} : {label}")
# Out:
# Label for text 0 : neutral
# Label for text 1 : neutral
# Label for text 2 : neutral
# Label for text 3 : neutral
# Label for text 4 : positive
# Label for text 5 : neutral
# Label for text 6 : neutral
# Label for text 7 : positive
# Label for text 8 : neutral
# Label for text 9 : neutral
# Label for text 10 : neutral
# Label for text 11 : neutral
# Label for text 12 : neutral
# Label for text 13 : neutral
# Label for text 14 : neutral
# Label for text 15 : neutral
# Label for text 16 : neutral
# Label for text 17 : neutral
# Label for text 18 : neutral
# Label for text 19 : neutral
# Label for text 20 : neutral
# Label for text 21 : neutral
# Label for text 22 : neutral
# Label for text 23 : neutral
# Label for text 24 : neutral
# Label for text 25 : neutral
# Label for text 26 : neutral
# Label for text 27 : neutral
# Label for text 28 : neutral
# Label for text 29 : neutral
# Label for text 30 : neutral
# Label for text 31 : neutral
# Label for text 32 : neutral
# Label for text 33 : neutral
# Label for text 34 : neutral
# Label for text 35 : neutral
# Label for text 36 : neutral
# Label for text 37 : neutral
# Label for text 38 : positive
# Label for text 39 : neutral
# Label for text 40 : positive
# Label for text 41 : neutral
# Label for text 42 : positive
# Label for text 43 : neutral
# Label for text 44 : neutral
# Label for text 45 : negative
# Label for text 46 : neutral
# Label for text 47 : neutral
# Label for text 48 : neutral
# Label for text 49 : neutral
# Label for text 50 : neutral
# Label for text 51 : neutral
# Label for text 52 : negative
# Label for text 53 : neutral
# Label for text 54 : positive
# Label for text 55 : neutral
# Label for text 56 : positive
# Label for text 57 : neutral
# Label for text 58 : neutral
# Label for text 59 : neutral
# Label for text 60 : neutral
# Label for text 61 : neutral
# Label for text 62 : positive
# Label for text 63 : neutral
# Label for text 64 : neutral
# Label for text 65 : neutral
# Label for text 66 : neutral
# Label for text 67 : neutral
# Label for text 68 : neutral
# Label for text 69 : positive
# Label for text 70 : neutral
# Label for text 71 : neutral
# Label for text 72 : neutral
# Label for text 73 : positive
# Label for text 74 : neutral
# Label for text 75 : neutral
# Label for text 76 : neutral
# Label for text 77 : neutral
# Label for text 78 : neutral
# Label for text 79 : neutral
# Label for text 80 : neutral
# Label for text 81 : neutral
# Label for text 82 : positive
# Label for text 83 : neutral
# Label for text 84 : neutral
# Label for text 85 : neutral
# Label for text 86 : neutral
# Label for text 87 : neutral
# Label for text 88 : positive
# Label for text 89 : neutral
# Label for text 90 : neutral
# Label for text 91 : positive
# Label for text 92 : positive
# Label for text 93 : neutral
# Label for text 94 : neutral
# Label for text 95 : neutral
# Label for text 96 : neutral
# Label for text 97 : neutral
# Label for text 98 : neutral
# Label for text 99 : neutral
